# %% [markdown]
# ## 03: Longest Substring Without Repeating Characters
#
# Given a string s, find the length of the longest substring without repeating characters.
#
# <b>Example 1:</b>
#
# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3.
#
# <b>Example 2</b>:
#
# Input: s = "bbbbb"
# Output: 1
# Explanation: The answer is "b", with the length of 1.
#
# <b>Example 3:</b>
#
# Input: s = "pwwkew"
# Output: 3
# Explanation: The answer is "wke", with the length of 3.
# Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.

# %%
def lengthOfLongestSubstring(s):
    length = len(s)
    if length <= 1:
        return length
    left = 0
    right = 0
    currLen = 0
    maxLen = 0
    hashmap = {}
    while right < length:
        char = s[right]
        if char in hashmap and hashmap[char] >= left:
            currLen = right - left
            maxLen = max(maxLen,currLen)
            left = hashmap[char] + 1
            hashmap[char] = right
            right += 1
        else:
            hashmap[char] = right
            right += 1
            currLen = right - left
    return max(maxLen,currLen)
        
            

s0 = "abba"
s1 = "abcabcbb"
s2 = "bbbbb"
s3 = "pwwkew"
s4 = " "
s5 = "au"
s6 = "tmmzuxt"

assert(lengthOfLongestSubstring(s0)==2)
assert(lengthOfLongestSubstring(s1)==3)
assert(lengthOfLongestSubstring(s2)==1)
assert(lengthOfLongestSubstring(s3)==3)
assert(lengthOfLongestSubstring(s4)==1)
assert(lengthOfLongestSubstring(s5)==2)
assert(lengthOfLongestSubstring(s6)==5)

# %%
def lengthOfLongestSubstring(s):
    length = len(s)
    left = 0
    right = 0
    maxLen = 0
    currLen = 0
    hashmap = {}
    for i in range(length):
        char = s[i]
        if char in hashmap and hashmap[char] >= left:
            currLen = right - left
            maxLen = max(maxLen,currLen)
            left = hashmap[char] + 1
            hashmap[char] = right
            right += 1
        else:
            hashmap[char] = right
            right += 1
            currLen = right - left
    return max(currLen,maxLen)
s0 = "abba"
s1 = "abcabcbb"
s2 = "bbbbb"
s3 = "pwwkew"
s4 = " "
s5 = "au"
s6 = "tmmzuxt"

assert(lengthOfLongestSubstring(s0)==2)
assert(lengthOfLongestSubstring(s1)==3)
assert(lengthOfLongestSubstring(s2)==1)
assert(lengthOfLongestSubstring(s3)==3)
assert(lengthOfLongestSubstring(s4)==1)
assert(lengthOfLongestSubstring(s5)==2)
assert(lengthOfLongestSubstring(s6)==5)

# %%
def lengthOfLongestSubstring(s):
    length = len(s)
    if length <= 1:
        return length
    left = 0
    right = 0
    hashmap = {}
    currLen = 0
    maxLen = 0
    for i in range(length):
        char = s[i]
        if char in hashmap and hashmap[char] >= left:
            currLen = right - left
            maxLen = max(currLen,maxLen)
            left = hashmap[char] + 1
            hashmap[char] = right
            right += 1
        else:
            hashmap[char] = right
            right += 1
            currLen = right - left
    return max(currLen,maxLen)

# %%
s0 = "abba"
s1 = "abcabcbb"
s2 = "bbbbb"
s3 = "pwwkew"
s4 = " "
s5 = "au"
s6 = "tmmzuxt"

assert(lengthOfLongestSubstring(s0)==2)
assert(lengthOfLongestSubstring(s1)==3)
assert(lengthOfLongestSubstring(s2)==1)
assert(lengthOfLongestSubstring(s3)==3)
assert(lengthOfLongestSubstring(s4)==1)
assert(lengthOfLongestSubstring(s5)==2)
assert(lengthOfLongestSubstring(s6)==5)

# %%
def lengthOfLongestSubstring(s):
    n = len(s)
    maxLen = 0
    # mp stores the current index of a character
    hashmap = {}

    left = 0
    # try to extend the range [i, j]
    for right in range(n):
        if s[right] in hashmap:
            left = max(hashmap[s[right]], left)

        maxLen = max(maxLen, right - left + 1)
        hashmap[s[right]] = right + 1

    return maxLen

s0 = "abba"
s1 = "abcabcbb"
s2 = "bbbbb"
s3 = "pwwkew"
s4 = " "
s5 = "au"
s6 = "tmmzuxt"

assert(lengthOfLongestSubstring(s0)==2)
assert(lengthOfLongestSubstring(s1)==3)
assert(lengthOfLongestSubstring(s2)==1)
assert(lengthOfLongestSubstring(s3)==3)
assert(lengthOfLongestSubstring(s4)==1)
assert(lengthOfLongestSubstring(s5)==2)
assert(lengthOfLongestSubstring(s6)==5)
